# %% [markdown]
# DATA
# Understandins

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\aniket\anaconda3\anaconda\lib\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.26.0 in c:\users\aniket\anaconda3\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aniket\anaconda3\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aniket\anaconda3\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aniket\anaconda3\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\aniket\anaconda3\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\aniket\anaconda3\anaconda\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\aniket\anaconda3\anaconda\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\aniket\anaconda3\anaconda\lib\site-packages (from xgboost) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv("Downloads/online_exam_cheating_risk_dataset.csv")

# %%
df.head()
# Out:
#    exam_duration_minutes  time_taken_to_start  tab_switch_count  \
# 0                     60                    3                 3
# 1                     86                    4                 5
# 2                     58                    8                 3
# 3                     40                    0                 5
# 4                     36                    9                 5
#
#    fullscreen_exit_count  copy_paste_attempts  device_switch_count  \
# 0                      1                    1                    0
# 1                      0                    0                    0
# 2                      1                    0                    1
# 3                      1                    3                    0
# 4                      2                    1                    1
#
#    ip_address_change  mouse_movement_speed  inactivity_time  \
# 0                  0                   595              138
# 1                  0                   554              102
# 2                  0                   703              125
# 3                  0                   390               82
# 4                  0                   686              224
#
#    question_skip_count  revisits_count  login_attempts  network_instability  \
# 0                    4              19               4                    0
# 1                    6               8               4                    2
# 2                    5              16               1                    1
# 3                    1               0               2                    0
# 4                    8              23               4                    0
#
#    webcam_disabled_flag  background_noise_flag  exam_time_remaining  \
# 0                     0                      0                   25
# 1                     0                      0                   18
# 2                     0                      0                   27
# 3                     0                      0                   25
# 4                     1                      1                   14
#
#    typing_speed  answer_change_count  suspicious_activity_score  cheating_risk
# 0            41                    1                          9              1
# 1            41                   11                          9              1
# 2            37                   11                          6              1
# 3            36                    7                         11              0
# 4            41                   14                         13              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   exam_duration_minutes      12000 non-null  int64
#  1   time_taken_to_start        12000 non-null  int64
#  2   tab_switch_count           12000 non-null  int64
#  3   fullscreen_exit_count      12000 non-null  int64
#  4   copy_paste_attempts        12000 non-null  int64
#  5   device_switch_count        12000 non-null  int64
#  6   ip_address_change          12000 non-null  int64
#  7   mouse_movement_speed       12000 non-null  int64
#  8   inactivity_time            12000 non-null  int64
#  9   question_skip_count        12000 non-null  int64
#  10  revisits_count             12000 non-null  int64
#  11  login_attempts             12000 non-null  int64
#  12  network_instability        12000 non-null  int64
#  13  webcam_disabled_flag       12000 non-null  int64
#  14  background_noise_flag      12000 non-null  int64
#  15  exam_time_remaining        12000 non-null  int64
#  16  typing_speed               12000 non-null  int64
#  17  answer_change_count        12000 non-null  int64
#  18  suspicious_activity_score  12000 non-null  int64
#  19  cheating_risk              12000 non-null  int64
# dtypes: int64(20)
# memory usage: 1.8 MB

# %%
df.describe()
# Out:
#        exam_duration_minutes  time_taken_to_start  tab_switch_count  \
# count           12000.000000          12000.00000      12000.000000
# mean               61.704833              3.41825          4.435167
# std                24.498869              2.54536          2.193102
# min                30.000000              0.00000          0.000000
# 25%                41.000000              1.00000          3.000000
# 50%                60.000000              3.00000          4.000000
# 75%                79.000000              5.00000          6.000000
# max               171.000000             13.00000         13.000000
#
#        fullscreen_exit_count  copy_paste_attempts  device_switch_count  \
# count           12000.000000         12000.000000         12000.000000
# mean                1.424833             0.653750             0.258583
# std                 1.247055             0.785013             0.524475
# min                 0.000000             0.000000             0.000000
# 25%                 0.000000             0.000000             0.000000
# 50%                 1.000000             0.000000             0.000000
# 75%                 2.000000             1.000000             0.000000
# max                 6.000000             5.000000             4.000000
#
#        ip_address_change  mouse_movement_speed  inactivity_time  \
# count       12000.000000          12000.000000      12000.00000
# mean            0.086833            529.420583         90.94550
# std             0.281602             99.738964         39.98765
# min             0.000000            173.000000          0.00000
# 25%             0.000000            461.000000         62.00000
# 50%             0.000000            527.000000         87.00000
# 75%             0.000000            595.000000        115.00000
# max             1.000000            950.000000        302.00000
#
#        question_skip_count  revisits_count  login_attempts  \
# count         12000.000000    12000.000000    12000.000000
# mean              4.180917       13.747000        1.690083
# std               3.817294        9.830101        1.017655
# min               0.000000        0.000000        1.000000
# 25%               1.000000        6.000000        1.000000
# 50%               4.000000       13.000000        1.000000
# 75%               7.000000       20.000000        2.000000
# max              22.000000       60.000000        8.000000
#
#        network_instability  webcam_disabled_flag  background_noise_flag  \
# count         12000.000000          12000.000000           12000.000000
# mean              0.780083              0.124167               0.168917
# std               0.962703              0.329785               0.374694
# min               0.000000              0.000000               0.000000
# 25%               0.000000              0.000000               0.000000
# 50%               1.000000              0.000000               0.000000
# 75%               1.000000              0.000000               0.000000
# max               6.000000              1.000000               1.000000
#
#        exam_time_remaining  typing_speed  answer_change_count  \
# count         12000.000000   12000.00000         12000.000000
# mean             15.826667      40.32200             9.361000
# std               9.664345       6.24471             7.239041
# min               0.000000      19.00000             0.000000
# 25%               9.000000      36.00000             3.000000
# 50%              16.000000      40.00000             9.000000
# 75%              22.000000      45.00000            14.000000
# max              57.000000      62.00000            42.000000
#
#        suspicious_activity_score  cheating_risk
# count               12000.000000   12000.000000
# mean                    8.462417       0.500000
# std                     3.079076       0.500021
# min                     1.000000       0.000000
# 25%                     6.000000       0.000000
# 50%                     8.000000       0.500000
# 75%                    10.000000       1.000000
# max                    23.000000       1.000000

# %%
df.dtypes
# Out:
# exam_duration_minutes        int64
# time_taken_to_start          int64
# tab_switch_count             int64
# fullscreen_exit_count        int64
# copy_paste_attempts          int64
# device_switch_count          int64
# ip_address_change            int64
# mouse_movement_speed         int64
# inactivity_time              int64
# question_skip_count          int64
# revisits_count               int64
# login_attempts               int64
# network_instability          int64
# webcam_disabled_flag         int64
# background_noise_flag        int64
# exam_time_remaining          int64
# typing_speed                 int64
# answer_change_count          int64
# suspicious_activity_score    int64
# cheating_risk                int64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Univariate Analysis

# %%
#Histogram
plt.hist(df["copy_paste_attempts"],bins=10)
plt.title("Histogram of copy_paste_attempts")
plt.xlabel("copy_paste_attempts")
plt.ylabel('Frequency')
plt.figure()

# %%
plt.hist(df["exam_duration_minutes"],bins=10)
plt.title("Histogram of exam_duration_minutes")
plt.xlabel("exam_duration_minutes")
plt.ylabel('Frequency')
plt.figure()

# %%
plt.hist(df["suspicious_activity_score"],bins=10)
plt.title("Histogram of suspicious_activity_score distribution")
plt.xlabel("suspicious_activity_score")
plt.ylabel('Friquency')
plt.figure()

# %%
#Boxplot
sns.boxplot(x="cheating_risk", y="mouse_movement_speed", data=df)
plt.title("mouse_movement_speed wise cheating_risk")
plt.xlabel("cheating_risk")
plt.ylabel("(mouse_movement_speed")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Step 3: Bivariate Analysis.
# Perform feature-to-feature analysis across all meaningful pairs. Use scatter plots, grouped aggregations, and
# comparative plots to understand relationships and dependencies between variables.

# %%
#scatter plot
plt.scatter(df["revisits_count"],df["mouse_movement_speed"])
plt.xlabel("revisits_count")
plt.ylabel("mouse_movement_speed")
plt.title("revisits_count wise mouse_movement_speed")
plt.show()

# %%
plt.scatter(df["question_skip_count"],df["fullscreen_exit_count"])
plt.xlabel("question_skip_count")
plt.ylabel("fullscreen_exit_count")
plt.title("question_skip_count wise fullscreen_exit_count")
plt.show()

# %%
plt.scatter(df["answer_change_count"],df["device_switch_count"])
plt.xlabel("answer_change_count")
plt.ylabel("device_switch_count")
plt.title("answer_change_count wise device_switch_count")
plt.show()

# %% [markdown]
# grouped aggregations

# %%
df.groupby('revisits_count')['ip_address_change'].mean()
# Out:
# revisits_count
# 0     0.084892
# 1     0.078261
# 2     0.060150
# 3     0.063694
# 4     0.062696
# 5     0.062696
# 6     0.064690
# 7     0.063232
# 8     0.082294
# 9     0.064198
# 10    0.068584
# 11    0.096330
# 12    0.080000
# 13    0.088993
# 14    0.093023
# 15    0.073069
# 16    0.093137
# 17    0.086124
# 18    0.107692
# 19    0.086294
# 20    0.091429
# 21    0.121495
# 22    0.077882
# 23    0.081356
# 24    0.071970
# 25    0.084444
# 26    0.138756
# 27    0.121547
# 28    0.143750
# 29    0.101266
# 30    0.091667
# 31    0.137405
# 32    0.123711
# 33    0.158537
# 34    0.114754
# 35    0.093750
# 36    0.100000
# 37    0.190476
# 38    0.102564
# 39    0.222222
# 40    0.178571
# 41    0.117647
# 42    0.066667
# 43    0.083333
# 44    0.000000
# 45    0.000000
# 46    0.000000
# 47    0.285714
# 48    0.333333
# 49    0.000000
# 50    0.000000
# 52    0.000000
# 60    0.000000
# Name: ip_address_change, dtype: float64

# %%
df.groupby('answer_change_count')['inactivity_time'].mean()
# Out:
# answer_change_count
# 0      80.531367
# 1      85.658263
# 2      85.912114
# 3      84.530271
# 4      84.475000
# 5      85.587037
# 6      84.525455
# 7      90.908582
# 8      90.789753
# 9      86.735495
# 10     90.299830
# 11     92.783542
# 12     91.183824
# 13     96.874088
# 14     98.839207
# 15     97.196682
# 16     98.880299
# 17     98.114525
# 18     95.227273
# 19     97.292517
# 20    101.946502
# 21     99.208333
# 22    108.082278
# 23    107.424242
# 24    105.676768
# 25    112.882353
# 26    109.333333
# 27    124.340000
# 28    118.742857
# 29    112.151515
# 30    121.904762
# 31    132.600000
# 32    145.875000
# 33    135.000000
# 34    127.800000
# 35    125.500000
# 36    140.000000
# 37    170.500000
# 38    173.000000
# 39     66.000000
# 40    119.000000
# 41    141.000000
# 42    129.000000
# Name: inactivity_time, dtype: float64

# %% [markdown]
# Comparative Plot(Blox plot for compative)

# %%
#Bivariate box plot
plt.figure(figsize=(10,6))
sns.boxplot(x="question_skip_count",y="time_taken_to_start",hue="background_noise_flag",data=df)
plt.title("typing speed vs Cheating Risk by Webcam Status")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="copy_paste_attempts",y="suspicious_activity_score",hue="cheating_risk",data=df)
plt.title("inactivity time vs Cheating Risk")
plt.show()

# %% [markdown]
# step 4: Target Relationship Analysis.
# Evaluate how each feature relates to the target variable using suitable visualizations and grouped statistics.
# Repeat this for every feature.

# %%
sns.boxplot(y=df['typing_speed'])
plt.show()

# %%
#Step 5: Multivariate Analysis 
#Use correlation heatmaps and other multivariate techniques to identify the strongest combined relationships
#among features.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.regplot(x="suspicious_activity_score",y="cheating_risk",data=df)
plt.ylabel("suspicious_activity_score")
plt.xlabel("cheating_risk")
plt.show()

# %%
sns.pairplot(df[["suspicious_activity_score","tab_switch_count","copy_paste_attempts","inactivity_time","cheating_risk"]])
plt.show()

# %% [markdown]
# Step 6: Data Preprocessing

# %% [markdown]
# Handle missing values, encode categorical/binary variables where required, and scale numerical features if needed

# %%
df.isnull().sum()
# Out:
# exam_duration_minutes        0
# time_taken_to_start          0
# tab_switch_count             0
# fullscreen_exit_count        0
# copy_paste_attempts          0
# device_switch_count          0
# ip_address_change            0
# mouse_movement_speed         0
# inactivity_time              0
# question_skip_count          0
# revisits_count               0
# login_attempts               0
# network_instability          0
# webcam_disabled_flag         0
# background_noise_flag        0
# exam_time_remaining          0
# typing_speed                 0
# answer_change_count          0
# suspicious_activity_score    0
# cheating_risk                0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
ch=df["cheating_risk"]
ch_encoded = encoder.fit_transform(ch)
print(ch_encoded)
print("Mapping:",dict(zip(encoder.classes_, range(len(encoder.classes_)))))
# Out:
# [1 1 1 ... 0 1 1]
# Mapping: {0: 0, 1: 1}

# %% [markdown]
# Step 7: Feature Engineering

# %% [markdown]
# Create new meaningful features based on domain understanding (example: combining multiple activity indicators
# into a single score).

# %%
df["behavioral_risk_score"] = (
    df["tab_switch_count"] +
    df["fullscreen_exit_count"] +
    df["copy_paste_attempts"] +
    df["device_switch_count"] +
    df["ip_address_change"]
)
df.head()
# Out:
#    exam_duration_minutes  time_taken_to_start  tab_switch_count  \
# 0                     60                    3                 3
# 1                     86                    4                 5
# 2                     58                    8                 3
# 3                     40                    0                 5
# 4                     36                    9                 5
#
#    fullscreen_exit_count  copy_paste_attempts  device_switch_count  \
# 0                      1                    1                    0
# 1                      0                    0                    0
# 2                      1                    0                    1
# 3                      1                    3                    0
# 4                      2                    1                    1
#
#    ip_address_change  mouse_movement_speed  inactivity_time  \
# 0                  0                   595              138
# 1                  0                   554              102
# 2                  0                   703              125
# 3                  0                   390               82
# 4                  0                   686              224
#
#    question_skip_count  ...  login_attempts  network_instability  \
# 0                    4  ...               4                    0
# 1                    6  ...               4                    2
# 2                    5  ...               1                    1
# 3                    1  ...               2                    0
# 4                    8  ...               4                    0
#
#    webcam_disabled_flag  background_noise_flag  exam_time_remaining  \
# 0                     0                      0                   25
# 1                     0                      0                   18
# 2                     0                      0                   27
# 3                     0                      0                   25
# 4                     1                      1                   14
#
#    typing_speed  answer_change_count  suspicious_activity_score  \
# 0            41                    1                          9
# 1            41                   11                          9
# 2            37                   11                          6
# 3            36                    7                         11
# 4            41                   14                         13
#
#    cheating_risk  behavioral_risk_score
# 0              1                      5
# 1              1                      5
# 2              1                      5
# 3              0                      9
# 4              1                      9
#
# [5 rows x 21 columns]

# %%
print(df.isnull().sum())
# Out:
# exam_duration_minutes        0
# time_taken_to_start          0
# tab_switch_count             0
# fullscreen_exit_count        0
# copy_paste_attempts          0
# device_switch_count          0
# ip_address_change            0
# mouse_movement_speed         0
# inactivity_time              0
# question_skip_count          0
# revisits_count               0
# login_attempts               0
# network_instability          0
# webcam_disabled_flag         0
# background_noise_flag        0
# exam_time_remaining          0
# typing_speed                 0
# answer_change_count          0
# suspicious_activity_score    0
# cheating_risk                0
# behavioral_risk_score        0
# dtype: int64

# %%
df = df[df["cheating_risk"].notnull()]

# %%
x= df.drop("cheating_risk", axis=1)
y= df["cheating_risk"]

# %% [markdown]
# Step 8: Train-Test Split

# %% [markdown]
# Split the dataset into training and testing sets using stratified sampling

# %%
from sklearn. model_selection import train_test_split

#Split into train (80%) and test (20%)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

print("Traning set size:", x_train.shape)   
print("Test set size:", x_test.shape)
print("cheating_risk distribution in Train:\n", y_train.value_counts(normalize=True))
print("sheating_risk distribution in Test:\n", y_test.value_counts(normalize=True))
# Out:
# Traning set size: (9600, 20)
# Test set size: (2400, 20)
# cheating_risk distribution in Train:
#  cheating_risk
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
# sheating_risk distribution in Test:
#  cheating_risk
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
print(y_test.isnull().sum())
# Out:
# 0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# Step 9: Model Building Train and compare multiple classification models such as Logistic Regression,
# Decision Tree, Random Forest, Gradient Boosting, XGBoost, and KNN.

# %% [markdown]
# Step 10: Model Evaluation Evaluate models using Accuracy, Precision, Recall, F1 Score,
# ROC-AUC Score, and Confusion Matrix. Compare results and select the best-performing model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, ConfusionMatrixDisplay, accuracy_score

log_reg = LogisticRegression(max_iter=1000, random_state=42)

log_reg.fit(x_train, y_train)

y_pred = log_reg.predict(x_test)
y_prob = log_reg.predict_proba(x_test)[:, 1] # probabilities for ROC-AOC

# %%
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score: 0.8245833333333333

# %%
print("Classification Report:/n", classification_report(y_test, y_pred))
# Out:
# Classification Report:/n               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      1200
#            1       0.84      0.80      0.82      1200
#
#     accuracy                           0.82      2400
#    macro avg       0.83      0.82      0.82      2400
# weighted avg       0.83      0.82      0.82      2400

# %%
ConfusionMatrixDisplay.from_estimator(log_reg, x_test, y_test,cmap="Blues")
plt.show()

# %%
print("ROC-AUC Score:", roc_auc_score(y_test, y_prob))
# Out:
# ROC-AUC Score: 0.9058715277777778

# %%
from sklearn.metrics import roc_curve

fpr, tpr, _=roc_curve(y_test,y_prob)
plt.plot(fpr,tpr,label="GradientBoostingClassifier")
plt.plot([0,1],[0,1],'--',color="gray")
plt.xlabel("false positive rate")
plt.ylabel("true positive rate")
plt.title("ROC curve")
plt.legend()
plt.show()

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, ConfusionMatrixDisplay, accuracy_score

XGBCla= XGBClassifier(random_state=42)

XGBCla.fit(x_train, y_train)

y_pred = XGBCla.predict(x_test)
y_prob = XGBCla.predict_proba(x_test)[:, 1]

# %%
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score: 0.8025

# %%
print("Classification Report:/n", classification_report(y_test, y_pred))
# Out:
# Classification Report:/n               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80      1200
#            1       0.81      0.80      0.80      1200
#
#     accuracy                           0.80      2400
#    macro avg       0.80      0.80      0.80      2400
# weighted avg       0.80      0.80      0.80      2400

# %%
ConfusionMatrixDisplay.from_estimator(XGBCla,x_test,y_test,cmap="Blues")
plt.show()

# %%
print("ROC-AUC Score:", roc_auc_score(y_test, y_prob))
# Out:
# ROC-AUC Score: 0.8862513888888889

# %%
from sklearn.metrics import roc_curve

fpr, tpr, _=roc_curve(y_test,y_prob)
plt.plot(fpr,tpr,label="KNeighborsClassifier")
plt.plot([0,1],[0,1],'--',color="gray")
plt.xlabel("false positive rate")
plt.ylabel("true positive rate")
plt.title("ROC curve")
plt.legend()
plt.show()
